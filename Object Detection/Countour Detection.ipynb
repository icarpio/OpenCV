# %% [markdown]
# # Contour Detection

# %%
'''Are a useful tool for shape analysis and object detection and recognition.
OpenCV has built in Counter finder function that can also helps us differentiate between internal and external contours'''

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('internal_external.png',0)

# %%
img.shape
# Out:
# (652, 1080)

# %%
plt.imshow(img,cmap='gray')

# %%
'''cv2.RETR_EXTERNAL:Only extracts external contours
cv2.RETR_CCOMP: Extracts both internal and external contours organized in a two-level hierarchy
cv2.RETR_TREE: Extracts both internal and external contours organized in a tree graph
cv2.RETR_LIST: Extracts all contours without any internal/external relationship'''
contours,hierarchy = cv2.findContours(img,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

# %%
type(hierarchy)
# Out:
# numpy.ndarray

# %%
external_contours = np.zeros(img.shape)
external_contours.shape
# Out:
# (652, 1080)

# %%
plt.imshow(img)

# %%
for i in range(len(contours)):
    
    #External
    if hierarchy[0][i][3] == -1:
        cv2.drawContours(external_contours,contours,i,255,-1)

# %%
plt.imshow(external_contours)

# %%
internal_contours = np.zeros(img.shape)
for i in range(len(contours)):
    
    # Internal
    if hierarchy[0][i][3] != -1:
        cv2.drawContours(internal_contours,contours,i,255,-1)
        
plt.imshow(internal_contours,cmap='gray')
